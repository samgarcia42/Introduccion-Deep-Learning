# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/Prevent_Overfitting.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %% [markdown]
# # Prevent Overfitting: Regularization

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
tf.random.set_seed(0)

# %% [markdown]
# We will use the [MNIST dataset](https://en.wikipedia.org/wiki/MNIST_database), consisting of a collection of 28x28 pixel images corresponding in digits from 0 to 9 manuscripts. The purpose of this data set is to train models that recognize handwritten numbers.
#
# We will train, therefore, an [OCR (Optical Character Recognition)](https://en.wikipedia.org/wiki/Optical_character_recognition) model for multiclass classification (numbers from 0 to 9).

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train[0].shape
# Out:
# (28, 28)

# %% [markdown]
# As they are 8-bit images, the colors (in this case only one channel, the gray channel) of each pixel are encoded with a value between 0 and 255, with 0 being black and 255 being white. It is usual to normalize the values to work with a range between 0.0 and 1.0.

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# We visualize a random image of the training set.

# %%
import numpy as np

i = np.random.randint(0, len(x_train))
plt.imshow(x_train[i], cmap='gray')
plt.show()

# %% [markdown]
# We reduce the dataset for  inducing more overfitting

# %%
from sklearn.model_selection import train_test_split
# split into train test sets
_, x, _, y = train_test_split(
    x_train, y_train, test_size=0.02, random_state=1, stratify=y_train)

num_classes = 10
from collections import Counter
x.shape, y.shape, Counter(y)
# Out:
# ((1200, 28, 28),
#  (1200,),
#  Counter({np.uint8(2): 119,
#           np.uint8(8): 117,
#           np.uint8(6): 118,
#           np.uint8(9): 119,
#           np.uint8(3): 123,
#           np.uint8(4): 117,
#           np.uint8(0): 119,
#           np.uint8(7): 125,
#           np.uint8(5): 108,
#           np.uint8(1): 135}))

# %% [markdown]
# #### Why do we need to use regularization?
#
# We are going to assign the classes randomly to each image with random shuffle.

# %%
y_shuffle = np.copy(y)
np.random.shuffle(y_shuffle)
y[:5], y_shuffle[:5]
# Out:
# (array([2, 8, 6, 9, 3], dtype=uint8), array([1, 4, 0, 3, 5], dtype=uint8))

# %%
fig, axes = plt.subplots(3, 3, figsize=(9, 9))
axes = axes.ravel()

for i in np.arange(0, 9):
    ind = np.random.randint(len(y_shuffle))
    axes[i].imshow(x[ind].reshape(28, 28))
    axes[i].set_title(
        f"Digit = {y_shuffle[ind]}")
    axes[i].axis('off')

plt.subplots_adjust(wspace=0.3)

# %% [markdown]
# Lets build a model for learning the new random classes

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28))
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(64, activation='relu')(flat)
# hidden layer 2
l_2 = layers.Dense(64, activation='relu')(l_1)
# hidden layer 3
l_3 = layers.Dense(64, activation='relu')(l_2)

# Outputs
outputs = layers.Dense(10, activation='softmax')(l_3)

# Model definition
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(
    x,
    y_shuffle,
    batch_size=64,
    epochs=100,
    shuffle=True
)
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0844 - loss: 2.3256
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1358 - loss: 2.2780
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2023 - loss: 2.2417
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2353 - loss: 2.1972
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2401 - loss: 2.1511
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2764 - loss: 2.0922
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2954 - loss: 2.0204
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3450 - loss: 1.9377
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3701 - loss: 1.8428
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4063 - loss: 1.7455
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4528 - loss: 1.6354
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5138 - loss: 1.5169
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5732 - loss: 1.3969
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6284 - loss: 1.2793
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6672 - loss: 1.1558
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7157 - loss: 1.0406
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7458 - loss: 0.9307
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7713 - loss: 0.8576
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7803 - loss: 0.7997
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8103 - loss: 0.7200
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7997 - loss: 0.6844
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8404 - loss: 0.6382
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8298 - loss: 0.6207
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8375 - loss: 0.5817
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8394 - loss: 0.5695
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7764 - loss: 0.7041
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7815 - loss: 0.7110
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8212 - loss: 0.5837
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8214 - loss: 0.5660
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8621 - loss: 0.4909
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9156 - loss: 0.3536
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9399 - loss: 0.3097
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9209 - loss: 0.3277
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9234 - loss: 0.3191
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9244 - loss: 0.3181
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9034 - loss: 0.3385
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8782 - loss: 0.3912
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8583 - loss: 0.4226
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9097 - loss: 0.3474
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9001 - loss: 0.3547
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8988 - loss: 0.3570
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8917 - loss: 0.3827
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8256 - loss: 0.5235
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8121 - loss: 0.5895
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9006 - loss: 0.3458
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9452 - loss: 0.2342
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9540 - loss: 0.2045
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9771 - loss: 0.1554
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9781 - loss: 0.1307
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9781 - loss: 0.1229
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9856 - loss: 0.1079
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9859 - loss: 0.1106
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9859 - loss: 0.0988
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0781
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0634
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9913 - loss: 0.0608
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0580
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9952 - loss: 0.0478
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9958 - loss: 0.0422
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0392
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0372
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0353
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0335
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9998 - loss: 0.0317
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0263
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0251
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0240
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0230
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0219
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0201
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0194
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0171
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0164
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0158
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0152
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0105
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0098
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0095
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0086
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0084
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0081
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0078

# %%
results = model.evaluate(x, y_shuffle, verbose=0)
print('Train Accuracy: {}'.format(results[1]))
# Out:
# Train Accuracy: 1.0

# %%
fig, axes = plt.subplots(3, 3, figsize=(9, 9))
axes = axes.ravel()

for i in np.arange(0, 9):
    ind = np.random.randint(len(y_shuffle))
    pred_pobs = model.predict(np.expand_dims(x[ind], 0)).flatten()
    pred_class = np.argmax(pred_pobs)
    prob = np.max(pred_pobs)
    axes[i].imshow(x[ind].reshape(28, 28))
    axes[i].set_title(
        f"Digit = {y_shuffle[ind]} \n Prediction={pred_class} , Prob={prob:.4f}")
    axes[i].axis('off')

plt.subplots_adjust(wspace=0.5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %% [markdown]
# We can see that the model has fully fitted the training set. It practically does not matter what data you introduce into the neural network, it will almost always fit. The objective is not to fit the training set, it is to **GENERALIZE**.

# %% [markdown]
# #### Regularization for preventing overfitting
#
# To get the model to **generalize**, we can use one of the numerous regularization techniques

# %% [markdown]
# We build a model consisting of:
#
# - Input with dimension (28,28)
# - Flatten layer
# - Dense hidden  layer with 256 neurons and ReLU as activation function
# - Second dense hidden layer with 128 neurons and ReLU as activation function
# - Third dense  hidden layer with 128 neurons and ReLU as activation function
# - Output layer with a single neuron that implements the sigmoid function.

# %%
# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

# Model definition
model = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 8.2654e-05 - val_accuracy: 0.9083 - val_loss: 0.4601
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 8.0692e-05 - val_accuracy: 0.9083 - val_loss: 0.4609
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.8693e-05 - val_accuracy: 0.9083 - val_loss: 0.4613
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.6829e-05 - val_accuracy: 0.9083 - val_loss: 0.4618
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 7.4988e-05 - val_accuracy: 0.9083 - val_loss: 0.4621

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5461183190345764
# Test Accuracy: 0.9093000292778015

# %% [markdown]
# We visualize the evolution of the values in each epoch of the loss function and accuracy.

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# %%
hist.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss  epoch
# 0  0.467708  1.836076      0.712500  1.153968      0
# 1  0.786458  0.750731      0.841667  0.537373      1
# 2  0.890625  0.367067      0.858333  0.467825      2
# 3  0.933333  0.230318      0.862500  0.505896      3
# 4  0.935417  0.193466      0.879167  0.414425      4

# %% [markdown]
# <a id='overfitting_results'></a>
# When interpreting both graphs, it is evident that the model over-fits the training values and is not able to generalize well for the validation values. **It is a clear example of overfitting**.
#
# The following function will be useful throughout the different practical examples.

# %%
import matplotlib.pyplot as plt

def show_loss_accuracy_evolution(history):

    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Categorical Crossentropy')
    ax1.plot(hist['epoch'], hist['loss'], label='Train Error')
    ax1.plot(hist['epoch'], hist['val_loss'], label = 'Val Error')
    ax1.grid()
    ax1.legend()

    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.plot(hist['epoch'], hist['accuracy'], label='Train Accuracy')
    ax2.plot(hist['epoch'], hist['val_accuracy'], label = 'Val Accuracy')
    ax2.grid()
    ax2.legend()

    plt.show()

def show_samples(x_test, y_test, model):
    predictions = model.predict(x_test)
    predicted_classes = np.argmax(predictions, -1)

    L = 5
    W = 5
    fig, axes = plt.subplots(L, W, figsize=(14, 14))
    axes = axes.ravel()

    for i in np.arange(0, L * W):
        ind = np.random.randint(len(y_test))
        axes[i].imshow(x_test[ind].reshape(28, 28))
        prob_pred = np.max(predictions[ind, :])
        class_pred = int(predicted_classes[ind])
        original_class = int(y_test[ind])
        if class_pred == original_class:
            color = 'green'
        else:
            color = 'red'
        title = "Pred: {0} \n Target: {1} \n Prob: {2:.3f}".format(
        class_pred, original_class, prob_pred)
        axes[i].set_title(title, color=color)
        axes[i].axis('off')

    plt.subplots_adjust(wspace=0.5)

# %%
show_loss_accuracy_evolution(history)

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5461183190345764
# Test Accuracy: 0.9093000292778015

# %%
show_samples(x_test, y_test, model)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ## Create a simpler model
#
# The simplest way to prevent overfitting is to create  a simple model: A model with less number of  parameters (which is determined by the number of layers and the number of units per layer).
#
# A more complex model with more parameters will have much more capacity and will be able to learn almost any training set. Deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.

# %%
# Input layer
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
flat = layers.Flatten()(inputs)

# First hidden layer
l_1 = layers.Dense(8, activation='relu', name='layer_1')(flat)

# Output layer
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_1)
model_simpler = keras.Model(
    inputs=inputs, outputs=outputs, name='simpler_model')

model_simpler.summary()
# Out:
# Model: "simpler_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 8)              │         6,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │            90 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,370 (24.88 KB)
#  Trainable params: 6,370 (24.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_simpler.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
history_simpler = model_simpler.fit(x,
                                    y,
                                    batch_size=64,
                                    epochs=100,
                                    validation_split=0.25,
                                    shuffle=True)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1014 - loss: 2.3305 - val_accuracy: 0.1800 - val_loss: 2.1589
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1909 - loss: 2.0830 - val_accuracy: 0.2600 - val_loss: 1.9631
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2795 - loss: 1.8692 - val_accuracy: 0.3633 - val_loss: 1.7876
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - loss: 0.0753 - val_accuracy: 0.8600 - val_loss: 0.4719
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9957 - loss: 0.0737 - val_accuracy: 0.8567 - val_loss: 0.4728
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9957 - loss: 0.0722 - val_accuracy: 0.8567 - val_loss: 0.4740
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9957 - loss: 0.0707 - val_accuracy: 0.8567 - val_loss: 0.4755
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9967 - loss: 0.0693 - val_accuracy: 0.8567 - val_loss: 0.4768
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9967 - loss: 0.0678 - val_accuracy: 0.8567 - val_loss: 0.4778
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9967 - loss: 0.0665 - val_accuracy: 0.8567 - val_loss: 0.4791
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9967 - loss: 0.0651 - val_accuracy: 0.8567 - val_loss: 0.4800
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9969 - loss: 0.0638 - val_accuracy: 0.8567 - val_loss: 0.4816
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9969 - loss: 0.0625 - val_accuracy: 0.8567 - val_loss: 0.4825
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9969 - loss: 0.0613 - val_accuracy: 0.8533 - val_loss: 0.4838
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9972 - loss: 0.0601 - val_accuracy: 0.8567 - val_loss: 0.4854
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9991 - loss: 0.0589 - val_accuracy: 0.8567 - val_loss: 0.4865
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0577 - val_accuracy: 0.8567 - val_loss: 0.4880
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0566 - val_accuracy: 0.8567 - val_loss: 0.4893
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9991 - loss: 0.0555 - val_accuracy: 0.8533 - val_loss: 0.4902
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9991 - loss: 0.0544 - val_accuracy: 0.8567 - val_loss: 0.4919

# %%
show_loss_accuracy_evolution(history_simpler)

# %%
results = model_simpler.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5480462908744812
# Test Accuracy: 0.8586999773979187

# %% [markdown]
# ## Reduce batch_size
#
# Other method is decreasing the `batch_size`during the gradient descend to add more uncertainty to the estimation of the parameter gradients, thus reducing the capacity of the model

# %%
# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

# Model definition
model = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model')
## same model
model.summary()
# Out:
# Model: "dont_overfit_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,658 (983.04 KB)
#  Trainable params: 251,658 (983.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_2 = model.fit(
    x,
    y,
    batch_size=16,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4373 - loss: 1.7236 - val_accuracy: 0.8708 - val_loss: 0.4646
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8535 - loss: 0.4703 - val_accuracy: 0.8875 - val_loss: 0.4099
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9246 - loss: 0.2309 - val_accuracy: 0.9000 - val_loss: 0.3674
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9649 - loss: 0.1239 - val_accuracy: 0.8875 - val_loss: 0.4107
# Epoch 5/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9926 - loss: 0.0631 - val_accuracy: 0.8708 - val_loss: 0.5013
# Epoch 6/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9925 - loss: 0.0424 - val_accuracy: 0.9000 - val_loss: 0.3906
# Epoch 7/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.8958 - val_loss: 0.4335
# Epoch 8/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9000 - val_loss: 0.4151
# Epoch 9/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8958 - val_loss: 0.4083
# Epoch 10/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8958 - val_loss: 0.4060
# Epoch 11/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9125 - val_loss: 0.4078
# Epoch 12/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9125 - val_loss: 0.4132
# Epoch 13/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9083 - val_loss: 0.4199
# Epoch 14/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9083 - val_loss: 0.4256
# Epoch 15/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.4279e-04 - val_accuracy: 0.9125 - val_loss: 0.4316
# Epoch 16/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.2182e-04 - val_accuracy: 0.9083 - val_loss: 0.4370
# Epoch 17/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.2530e-04 - val_accuracy: 0.9042 - val_loss: 0.4416
# Epoch 18/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.5068e-04 - val_accuracy: 0.9042 - val_loss: 0.4458
# Epoch 19/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.8856e-04 - val_accuracy: 0.9042 - val_loss: 0.4495
# Epoch 20/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.3664e-04 - val_accuracy: 0.9083 - val_loss: 0.4528
# Epoch 21/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.9305e-04 - val_accuracy: 0.9083 - val_loss: 0.4563
# Epoch 22/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.5520e-04 - val_accuracy: 0.9083 - val_loss: 0.4589
# Epoch 23/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 3.2258e-04 - val_accuracy: 0.9083 - val_loss: 0.4624
# Epoch 24/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.9408e-04 - val_accuracy: 0.9083 - val_loss: 0.4646
# Epoch 25/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.6887e-04 - val_accuracy: 0.9083 - val_loss: 0.4680
# Epoch 26/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.4666e-04 - val_accuracy: 0.9083 - val_loss: 0.4701
# Epoch 27/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.2685e-04 - val_accuracy: 0.9083 - val_loss: 0.4725
# Epoch 28/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.0901e-04 - val_accuracy: 0.9083 - val_loss: 0.4750
# Epoch 29/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.9297e-04 - val_accuracy: 0.9083 - val_loss: 0.4774
# Epoch 30/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.7868e-04 - val_accuracy: 0.9083 - val_loss: 0.4796
# Epoch 31/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.6560e-04 - val_accuracy: 0.9083 - val_loss: 0.4822
# Epoch 32/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.5371e-04 - val_accuracy: 0.9083 - val_loss: 0.4844
# Epoch 33/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.4283e-04 - val_accuracy: 0.9083 - val_loss: 0.4866
# Epoch 34/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.3293e-04 - val_accuracy: 0.9083 - val_loss: 0.4890
# Epoch 35/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.2402e-04 - val_accuracy: 0.9083 - val_loss: 0.4912
# Epoch 36/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.1579e-04 - val_accuracy: 0.9083 - val_loss: 0.4935
# Epoch 37/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.0820e-04 - val_accuracy: 0.9083 - val_loss: 0.4956
# Epoch 38/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.0129e-04 - val_accuracy: 0.9083 - val_loss: 0.4974
# Epoch 39/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.4874e-05 - val_accuracy: 0.9083 - val_loss: 0.4996
# Epoch 40/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.8919e-05 - val_accuracy: 0.9083 - val_loss: 0.5024
# Epoch 41/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.3529e-05 - val_accuracy: 0.9083 - val_loss: 0.5046
# Epoch 42/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.8368e-05 - val_accuracy: 0.9083 - val_loss: 0.5068
# Epoch 43/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.3702e-05 - val_accuracy: 0.9083 - val_loss: 0.5091
# Epoch 44/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 6.9271e-05 - val_accuracy: 0.9083 - val_loss: 0.5119
# Epoch 45/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.5168e-05 - val_accuracy: 0.9083 - val_loss: 0.5140
# Epoch 46/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.1328e-05 - val_accuracy: 0.9083 - val_loss: 0.5161
# Epoch 47/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.7771e-05 - val_accuracy: 0.9083 - val_loss: 0.5183
# Epoch 48/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.4434e-05 - val_accuracy: 0.9083 - val_loss: 0.5203
# Epoch 49/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 5.1329e-05 - val_accuracy: 0.9042 - val_loss: 0.5226
# Epoch 50/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 4.8512e-05 - val_accuracy: 0.9042 - val_loss: 0.5243
# Epoch 51/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 4.5831e-05 - val_accuracy: 0.9042 - val_loss: 0.5265
# Epoch 52/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.3348e-05 - val_accuracy: 0.9042 - val_loss: 0.5285
# Epoch 53/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.1037e-05 - val_accuracy: 0.9042 - val_loss: 0.5305
# Epoch 54/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.8884e-05 - val_accuracy: 0.9042 - val_loss: 0.5324
# Epoch 55/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.6816e-05 - val_accuracy: 0.9042 - val_loss: 0.5342
# Epoch 56/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.4893e-05 - val_accuracy: 0.9000 - val_loss: 0.5362
# Epoch 57/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 3.3099e-05 - val_accuracy: 0.9000 - val_loss: 0.5383
# Epoch 58/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 3.1418e-05 - val_accuracy: 0.9000 - val_loss: 0.5402
# Epoch 59/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.9824e-05 - val_accuracy: 0.9000 - val_loss: 0.5421
# Epoch 60/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.8321e-05 - val_accuracy: 0.9000 - val_loss: 0.5440
# Epoch 61/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.6935e-05 - val_accuracy: 0.9000 - val_loss: 0.5458
# Epoch 62/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.5590e-05 - val_accuracy: 0.9000 - val_loss: 0.5474
# Epoch 63/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.4349e-05 - val_accuracy: 0.9000 - val_loss: 0.5492
# Epoch 64/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.3190e-05 - val_accuracy: 0.9000 - val_loss: 0.5511
# Epoch 65/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.2049e-05 - val_accuracy: 0.9000 - val_loss: 0.5528
# Epoch 66/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.0999e-05 - val_accuracy: 0.9000 - val_loss: 0.5551
# Epoch 67/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.0031e-05 - val_accuracy: 0.9000 - val_loss: 0.5568
# Epoch 68/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.9073e-05 - val_accuracy: 0.9042 - val_loss: 0.5584
# Epoch 69/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.8160e-05 - val_accuracy: 0.9042 - val_loss: 0.5601
# Epoch 70/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.7315e-05 - val_accuracy: 0.9042 - val_loss: 0.5616
# Epoch 71/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.6509e-05 - val_accuracy: 0.9083 - val_loss: 0.5635
# Epoch 72/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.5742e-05 - val_accuracy: 0.9083 - val_loss: 0.5652
# Epoch 73/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.5022e-05 - val_accuracy: 0.9083 - val_loss: 0.5671
# Epoch 74/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.4336e-05 - val_accuracy: 0.9042 - val_loss: 0.5683
# Epoch 75/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 1.3697e-05 - val_accuracy: 0.9042 - val_loss: 0.5703
# Epoch 76/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.3080e-05 - val_accuracy: 0.9042 - val_loss: 0.5720
# Epoch 77/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 1.2505e-05 - val_accuracy: 0.9042 - val_loss: 0.5737
# Epoch 78/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.1953e-05 - val_accuracy: 0.9042 - val_loss: 0.5752
# Epoch 79/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 1.1427e-05 - val_accuracy: 0.9042 - val_loss: 0.5771
# Epoch 80/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0931e-05 - val_accuracy: 0.9042 - val_loss: 0.5786
# Epoch 81/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.0457e-05 - val_accuracy: 0.9042 - val_loss: 0.5801
# Epoch 82/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.0011e-05 - val_accuracy: 0.9042 - val_loss: 0.5819
# Epoch 83/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 9.5928e-06 - val_accuracy: 0.9042 - val_loss: 0.5833
# Epoch 84/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.1833e-06 - val_accuracy: 0.9042 - val_loss: 0.5851
# Epoch 85/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.7890e-06 - val_accuracy: 0.9042 - val_loss: 0.5868
# Epoch 86/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.4191e-06 - val_accuracy: 0.9042 - val_loss: 0.5884
# Epoch 87/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.0649e-06 - val_accuracy: 0.9042 - val_loss: 0.5898
# Epoch 88/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.7254e-06 - val_accuracy: 0.9042 - val_loss: 0.5915
# Epoch 89/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.4091e-06 - val_accuracy: 0.9042 - val_loss: 0.5932
# Epoch 90/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.1034e-06 - val_accuracy: 0.9042 - val_loss: 0.5946
# Epoch 91/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 6.8095e-06 - val_accuracy: 0.9042 - val_loss: 0.5965
# Epoch 92/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.5313e-06 - val_accuracy: 0.9042 - val_loss: 0.5981
# Epoch 93/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 6.2628e-06 - val_accuracy: 0.9042 - val_loss: 0.5994
# Epoch 94/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.0135e-06 - val_accuracy: 0.9042 - val_loss: 0.6012
# Epoch 95/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.7682e-06 - val_accuracy: 0.9042 - val_loss: 0.6027
# Epoch 96/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 5.5367e-06 - val_accuracy: 0.9042 - val_loss: 0.6043
# Epoch 97/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.3177e-06 - val_accuracy: 0.9042 - val_loss: 0.6058
# Epoch 98/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 5.1071e-06 - val_accuracy: 0.9042 - val_loss: 0.6075
# Epoch 99/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.9072e-06 - val_accuracy: 0.9042 - val_loss: 0.6090
# Epoch 100/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 4.7145e-06 - val_accuracy: 0.9042 - val_loss: 0.6106

# %%
show_loss_accuracy_evolution(history_2)

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6179956197738647
# Test Accuracy: 0.9138000011444092

# %% [markdown]
# ### Question 1:
# #### What differences do you see if you change the batch_size to a lower or higher value? For example to 1 and to 512

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_stochastic = model.fit(
    x,
    y,
    batch_size=1,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9035 - loss: 0.4931 - val_accuracy: 0.8625 - val_loss: 0.6017
# Epoch 2/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9503 - loss: 0.1906 - val_accuracy: 0.8083 - val_loss: 0.6436
# Epoch 3/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9660 - loss: 0.1072 - val_accuracy: 0.8667 - val_loss: 0.7218
# Epoch 4/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9507 - loss: 0.1746 - val_accuracy: 0.8958 - val_loss: 0.5478
# Epoch 5/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9241 - loss: 0.2561 - val_accuracy: 0.8958 - val_loss: 0.4950
# Epoch 6/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9786 - loss: 0.0921 - val_accuracy: 0.9042 - val_loss: 0.4740
# Epoch 7/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9849 - loss: 0.0486 - val_accuracy: 0.9083 - val_loss: 0.4342
# Epoch 8/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9840 - loss: 0.0786 - val_accuracy: 0.8833 - val_loss: 0.6261
# Epoch 9/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9718 - loss: 0.0899 - val_accuracy: 0.8875 - val_loss: 0.7106
# Epoch 10/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9635 - loss: 0.1248 - val_accuracy: 0.8917 - val_loss: 0.8100
# Epoch 11/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9415 - loss: 0.2455 - val_accuracy: 0.9292 - val_loss: 0.5669
# Epoch 12/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9125 - val_loss: 0.6895
# Epoch 13/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9912 - loss: 0.0390 - val_accuracy: 0.9000 - val_loss: 0.8590
# Epoch 14/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9833 - loss: 0.0604 - val_accuracy: 0.8875 - val_loss: 0.8901
# Epoch 15/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9615 - loss: 0.1891 - val_accuracy: 0.9125 - val_loss: 0.6467
# Epoch 16/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9916 - loss: 0.0444 - val_accuracy: 0.9375 - val_loss: 0.5435
# Epoch 17/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 8.5542e-04 - val_accuracy: 0.9417 - val_loss: 0.6429
# Epoch 18/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 5.1614e-05 - val_accuracy: 0.9375 - val_loss: 0.6743
# Epoch 19/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 2.2267e-05 - val_accuracy: 0.9375 - val_loss: 0.7110
# Epoch 20/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 1.0704e-05 - val_accuracy: 0.9333 - val_loss: 0.7504
# Epoch 21/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 5.0899e-06 - val_accuracy: 0.9375 - val_loss: 0.7899
# Epoch 22/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 2.3787e-06 - val_accuracy: 0.9333 - val_loss: 0.8290
# Epoch 23/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 1.1357e-06 - val_accuracy: 0.9333 - val_loss: 0.8626
# Epoch 24/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 5.7801e-07 - val_accuracy: 0.9333 - val_loss: 0.8923
# Epoch 25/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 3.0540e-07 - val_accuracy: 0.9333 - val_loss: 0.9179
# Epoch 26/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 1.6798e-07 - val_accuracy: 0.9375 - val_loss: 0.9405
# Epoch 27/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 9.5827e-08 - val_accuracy: 0.9375 - val_loss: 0.9632
# Epoch 28/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 5.4801e-08 - val_accuracy: 0.9375 - val_loss: 0.9864
# Epoch 29/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 3.0827e-08 - val_accuracy: 0.9375 - val_loss: 1.0078
# Epoch 30/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.8038e-08 - val_accuracy: 0.9375 - val_loss: 1.0276
# Epoch 31/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 9.9033e-09 - val_accuracy: 0.9375 - val_loss: 1.0443
# Epoch 32/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 7.0856e-09 - val_accuracy: 0.9375 - val_loss: 1.0603
# Epoch 33/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 3.1331e-09 - val_accuracy: 0.9375 - val_loss: 1.0742
# Epoch 34/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 1.6116e-09 - val_accuracy: 0.9375 - val_loss: 1.0858
# Epoch 35/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 1.1186e-09 - val_accuracy: 0.9375 - val_loss: 1.0954
# Epoch 36/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 8.8682e-10 - val_accuracy: 0.9375 - val_loss: 1.1087
# Epoch 37/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 1.0771e-10 - val_accuracy: 0.9375 - val_loss: 1.1223
# Epoch 38/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.0771e-10 - val_accuracy: 0.9375 - val_loss: 1.1370
# Epoch 39/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 1.1536
# Epoch 40/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 1.0771e-10 - val_accuracy: 0.9375 - val_loss: 1.1648
# Epoch 41/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9417 - val_loss: 1.1809
# Epoch 42/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9417 - val_loss: 1.1973
# Epoch 43/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9417 - val_loss: 1.2112
# Epoch 44/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9417 - val_loss: 1.2248
# Epoch 45/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9417 - val_loss: 1.2365
# Epoch 46/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.2468
# Epoch 47/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.2568
# Epoch 48/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.2649
# Epoch 49/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.2734
# Epoch 50/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.2821
# Epoch 51/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.2920
# Epoch 52/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.3025
# Epoch 53/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9954 - loss: 0.0570 - val_accuracy: 0.9000 - val_loss: 1.2774
# Epoch 54/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9704 - loss: 0.1522 - val_accuracy: 0.9375 - val_loss: 0.6940
# Epoch 55/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9784 - loss: 0.0844 - val_accuracy: 0.9167 - val_loss: 0.7593
# Epoch 56/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9167 - val_loss: 0.7451
# Epoch 57/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 3.3502e-05 - val_accuracy: 0.9167 - val_loss: 0.7508
# Epoch 58/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 2.1030e-05 - val_accuracy: 0.9208 - val_loss: 0.7589
# Epoch 59/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 1.3654e-05 - val_accuracy: 0.9250 - val_loss: 0.7663
# Epoch 60/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 8.7719e-06 - val_accuracy: 0.9292 - val_loss: 0.7777
# Epoch 61/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 3.9174e-06 - val_accuracy: 0.9333 - val_loss: 0.7890
# Epoch 62/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 2.0186e-06 - val_accuracy: 0.9333 - val_loss: 0.8060
# Epoch 63/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 1.0000 - loss: 1.1100e-06 - val_accuracy: 0.9333 - val_loss: 0.8236
# Epoch 64/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 5.8209e-07 - val_accuracy: 0.9333 - val_loss: 0.8377
# Epoch 65/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 3.0175e-07 - val_accuracy: 0.9292 - val_loss: 0.8521
# Epoch 66/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.5606e-07 - val_accuracy: 0.9292 - val_loss: 0.8646
# Epoch 67/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 8.1727e-08 - val_accuracy: 0.9292 - val_loss: 0.8761
# Epoch 68/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 1.0000 - loss: 4.5400e-08 - val_accuracy: 0.9292 - val_loss: 0.8886
# Epoch 69/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 2.3848e-08 - val_accuracy: 0.9292 - val_loss: 0.9005
# Epoch 70/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 1.4603e-08 - val_accuracy: 0.9333 - val_loss: 0.9118
# Epoch 71/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 8.0319e-09 - val_accuracy: 0.9333 - val_loss: 0.9239
# Epoch 72/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 4.4757e-09 - val_accuracy: 0.9333 - val_loss: 0.9357
# Epoch 73/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 2.2893e-09 - val_accuracy: 0.9333 - val_loss: 0.9467
# Epoch 74/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.0902e-09 - val_accuracy: 0.9333 - val_loss: 0.9578
# Epoch 75/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 7.7675e-10 - val_accuracy: 0.9333 - val_loss: 0.9718
# Epoch 76/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 1.0000 - loss: 3.7202e-10 - val_accuracy: 0.9375 - val_loss: 0.9839
# Epoch 77/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 1.0771e-10 - val_accuracy: 0.9375 - val_loss: 0.9931
# Epoch 78/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 1.0027
# Epoch 79/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 1.0131
# Epoch 80/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 1.0239
# Epoch 81/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0347
# Epoch 82/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0453
# Epoch 83/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0555
# Epoch 84/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0650
# Epoch 85/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0744
# Epoch 86/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0830
# Epoch 87/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0909
# Epoch 88/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.0980
# Epoch 89/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.1044
# Epoch 90/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.1102
# Epoch 91/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9333 - val_loss: 1.1154
# Epoch 92/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1202
# Epoch 93/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1246
# Epoch 94/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1287
# Epoch 95/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1325
# Epoch 96/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1360
# Epoch 97/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1394
# Epoch 98/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1424
# Epoch 99/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1454
# Epoch 100/100
# 960/960 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482

# %%
show_loss_accuracy_evolution(history_stochastic)
## el overfitting empeora al bajar el bactch_size a 1

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
history_3 = model.fit(
    x,
    y,
    batch_size=512,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 402ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1482
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1483
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1484
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9292 - val_loss: 1.1484

# %%
show_loss_accuracy_evolution(history_3)
# problema de overfitting grave

# %% [markdown]
# <a id='dropout'></a>
# ## Dropout
#
# Dropout, applied to a layer, consists of randomly "dropping out" (set to zero) a number of output features of the layer during training with a probability **p** (`dropout rate`).
#
# In `keras` you can introduce dropout in a network via the [Dropout layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout), which gets applied to the output of layer right before.
#
# ```python
# tf.keras.layers.Dropout(
#     rate, noise_shape=None, seed=None, **kwargs
# )
# ```
#
# With Functional API:
# ```python
# next_layer = layers.Dropout(0.4)(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.Dropout(0.4))
# ```

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

flat = layers.Dropout(0.5, name='dropout_flat')(flat)
# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.Dropout(0.5, name='dropout_l1')(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.Dropout(0.5, name='dropout_l2')(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)
l_3 = layers.Dropout(0.5, name='dropout_l3')(l_3)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)


model_dropout = keras.Model(
    inputs=inputs, outputs=outputs, name='dont_overfit_model_dropout')

# %%
model_dropout.summary()
# Out:
# Model: "dont_overfit_model_dropout"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_flat (Dropout)          │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l1 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l2 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l3 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,658 (983.04 KB)
#  Trainable params: 251,658 (983.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_dropout.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# %%
history_dropout = model_dropout.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.1131 - loss: 2.5507 - val_accuracy: 0.2083 - val_loss: 2.2375
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1674 - loss: 2.2882 - val_accuracy: 0.4417 - val_loss: 2.1747
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1876 - loss: 2.1963 - val_accuracy: 0.5417 - val_loss: 2.0571
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2273 - loss: 2.0939 - val_accuracy: 0.5750 - val_loss: 1.8441
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3376 - loss: 1.9341 - val_accuracy: 0.6750 - val_loss: 1.5757
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3747 - loss: 1.7504 - val_accuracy: 0.7250 - val_loss: 1.2951
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3996 - loss: 1.6282 - val_accuracy: 0.7917 - val_loss: 1.0574
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4838 - loss: 1.5116 - val_accuracy: 0.8125 - val_loss: 0.9481
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4967 - loss: 1.3693 - val_accuracy: 0.7958 - val_loss: 0.8522
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9965 - loss: 0.0127 - val_accuracy: 0.9292 - val_loss: 0.3256
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9957 - loss: 0.0131 - val_accuracy: 0.9208 - val_loss: 0.4214
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9944 - loss: 0.0179 - val_accuracy: 0.9167 - val_loss: 0.3788
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9928 - loss: 0.0172 - val_accuracy: 0.9292 - val_loss: 0.3740
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9957 - loss: 0.0124 - val_accuracy: 0.9125 - val_loss: 0.5594
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 0.9250 - val_loss: 0.4066
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9927 - loss: 0.0204 - val_accuracy: 0.9208 - val_loss: 0.4462
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9982 - loss: 0.0062 - val_accuracy: 0.9125 - val_loss: 0.4438
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9970 - loss: 0.0125 - val_accuracy: 0.9042 - val_loss: 0.4372
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9991 - loss: 0.0035 - val_accuracy: 0.9375 - val_loss: 0.4028
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9977 - loss: 0.0126 - val_accuracy: 0.9167 - val_loss: 0.4715
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9989 - loss: 0.0097 - val_accuracy: 0.9292 - val_loss: 0.3984
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9250 - val_loss: 0.4353
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9292 - val_loss: 0.4495
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9996 - loss: 0.0030 - val_accuracy: 0.9292 - val_loss: 0.4322
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9997 - loss: 0.0030 - val_accuracy: 0.9208 - val_loss: 0.4560
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9125 - val_loss: 0.4529
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9292 - val_loss: 0.4237
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9167 - val_loss: 0.4538
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9167 - val_loss: 0.4625
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9993 - loss: 0.0013 - val_accuracy: 0.9292 - val_loss: 0.4246
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9208 - val_loss: 0.4369
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.7823e-04 - val_accuracy: 0.9250 - val_loss: 0.4385
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.5272e-04 - val_accuracy: 0.9250 - val_loss: 0.4395
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9986 - loss: 0.0064 - val_accuracy: 0.9333 - val_loss: 0.4131
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9167 - val_loss: 0.4182
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9000 - val_loss: 0.4957
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9966 - loss: 0.0089 - val_accuracy: 0.9125 - val_loss: 0.4480
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9292 - val_loss: 0.4283
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.0060 - val_accuracy: 0.9250 - val_loss: 0.4518
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9208 - val_loss: 0.4722
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9208 - val_loss: 0.4715
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9333 - val_loss: 0.4500
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 5.1301e-04 - val_accuracy: 0.9292 - val_loss: 0.4401
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9292 - val_loss: 0.4081
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9250 - val_loss: 0.4206
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9208 - val_loss: 0.4675
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 7.8064e-04 - val_accuracy: 0.9208 - val_loss: 0.4904
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9208 - val_loss: 0.4377

# %%
show_loss_accuracy_evolution(history_dropout_1)
## Resultado: aumenta el overfitting al reducir el dropout de 0.5 a 0.1
## aumenta la funcion de perdida, mayor desviacion entre valores reales y predichos
## Sin embargo el accuracy aumento levemente

# %%
results = model_dropout_1.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5011714100837708
# Test Accuracy: 0.9218000173568726

# %%
## dropout 0.9
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

flat = layers.Dropout(0.9, name='dropout_flat')(flat)
# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.Dropout(0.9, name='dropout_l1')(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.Dropout(0.9, name='dropout_l2')(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)
l_3 = layers.Dropout(0.9, name='dropout_l3')(l_3)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)


model_dropout_9 = keras.Model(
    inputs=inputs, outputs=outputs, name='dont_overfit_model_dropout_9')

# %%
model_dropout_9.summary()
# Out:
# Model: "dont_overfit_model_dropout_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_flat (Dropout)          │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l1 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l2 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_l3 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 251,658 (983.04 KB)
#  Trainable params: 251,658 (983.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_dropout_9.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# %%
history_dropout_9 = model_dropout_9.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.1228 - loss: 27.2234 - val_accuracy: 0.0708 - val_loss: 2.3050
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0814 - loss: 23.1299 - val_accuracy: 0.0875 - val_loss: 2.3038
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1019 - loss: 2.3293 - val_accuracy: 0.1292 - val_loss: 2.3075

# %%
show_loss_accuracy_evolution(history_dropout_9)
## Resultado: disminuye el overfitting al incrementar el dropout de 0.5 a 0.9
## aumenta extremamente la funcion de perdida, mayor desviacion entre valores reales y predichos
## el accuracy cae por los suelos, esto refleja una malisima capacidad de prediccion

# %%
results = model_dropout_9.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 2.3024346828460693
# Test Accuracy: 0.11349999904632568

# %% [markdown]
# ## Batch Normalization
#
# [Batch normalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization) applies a transformation that maintains the mean output close to 0 and the output standard deviation close to 1.
#
#
# With Functional API:
# ```python
# next_layer = layers.BatchNormalization()(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.BatchNormalization())
# ```

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.BatchNormalization()(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.BatchNormalization()(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)




model_batch_norm = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_batch_norm')

# %%
model_batch_norm.summary()
# Out:
# Model: "dont_overfit_model_batch_norm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 253,194 (989.04 KB)
#  Trainable params: 252,426 (986.04 KB)
#  Non-trainable params: 768 (3.00 KB)

# %%
model_batch_norm.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_batch_norm = model_batch_norm.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.3825 - loss: 1.8720 - val_accuracy: 0.6958 - val_loss: 1.7530
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9022 - loss: 0.4273 - val_accuracy: 0.7917 - val_loss: 1.4126
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9754 - loss: 0.1747 - val_accuracy: 0.8625 - val_loss: 1.2137
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0741 - val_accuracy: 0.8833 - val_loss: 1.0570
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.8958 - val_loss: 0.9229
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.9083 - val_loss: 0.8088
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9083 - val_loss: 0.7131
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.9083 - val_loss: 0.6327
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9042 - val_loss: 0.5663
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9042 - val_loss: 0.5117
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.8917 - val_loss: 0.4670
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8958 - val_loss: 0.4311
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9000 - val_loss: 0.4023
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9000 - val_loss: 0.3793
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9000 - val_loss: 0.3614
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8958 - val_loss: 0.3475
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8958 - val_loss: 0.3371
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8958 - val_loss: 0.3293
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8917 - val_loss: 0.3237
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8958 - val_loss: 0.3199
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8958 - val_loss: 0.3174
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8958 - val_loss: 0.3161
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8875 - val_loss: 0.3155
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8875 - val_loss: 0.3155
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8875 - val_loss: 0.3160
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8875 - val_loss: 0.3168
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8958 - val_loss: 0.3178
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8958 - val_loss: 0.3190
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 9.4965e-04 - val_accuracy: 0.8958 - val_loss: 0.3204
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.9166e-04 - val_accuracy: 0.8958 - val_loss: 0.3219
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.3881e-04 - val_accuracy: 0.8958 - val_loss: 0.3234
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.9065e-04 - val_accuracy: 0.8958 - val_loss: 0.3249
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 7.4648e-04 - val_accuracy: 0.8958 - val_loss: 0.3263
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 7.0586e-04 - val_accuracy: 0.8958 - val_loss: 0.3276
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.6838e-04 - val_accuracy: 0.8958 - val_loss: 0.3292
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 6.3395e-04 - val_accuracy: 0.8958 - val_loss: 0.3308
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 6.0207e-04 - val_accuracy: 0.8958 - val_loss: 0.3321
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 5.7257e-04 - val_accuracy: 0.8958 - val_loss: 0.3335
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 5.4516e-04 - val_accuracy: 0.8958 - val_loss: 0.3349
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.1979e-04 - val_accuracy: 0.8958 - val_loss: 0.3362
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.9614e-04 - val_accuracy: 0.8958 - val_loss: 0.3375
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.7404e-04 - val_accuracy: 0.8958 - val_loss: 0.3387
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 4.5338e-04 - val_accuracy: 0.9000 - val_loss: 0.3398
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.1015e-04 - val_accuracy: 0.9000 - val_loss: 0.3670
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0770e-04 - val_accuracy: 0.9000 - val_loss: 0.3675
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0532e-04 - val_accuracy: 0.9000 - val_loss: 0.3680
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 1.0300e-04 - val_accuracy: 0.9000 - val_loss: 0.3685
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 1.0077e-04 - val_accuracy: 0.9000 - val_loss: 0.3689
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.8590e-05 - val_accuracy: 0.9000 - val_loss: 0.3694
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 9.6483e-05 - val_accuracy: 0.9000 - val_loss: 0.3699
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.4447e-05 - val_accuracy: 0.9000 - val_loss: 0.3704
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 9.2475e-05 - val_accuracy: 0.9000 - val_loss: 0.3708
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.0545e-05 - val_accuracy: 0.9000 - val_loss: 0.3713
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.8687e-05 - val_accuracy: 0.9000 - val_loss: 0.3718
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 8.6864e-05 - val_accuracy: 0.9000 - val_loss: 0.3722

# %%
show_loss_accuracy_evolution(history_batch_norm)

# %%
results = model_batch_norm.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.40885263681411743
# Test Accuracy: 0.8996000289916992

# %% [markdown]
# ## Layer Normalization
#
# [Layer normalization](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LayerNormalization) is another type of normalization technique. Unlike batch normalization, it normalizes the data across the features and is not dependent on the batch size, making it effective for both training and inference time normalization.
#
# Layer normalization computes the mean and variance used for normalization from all of the summed inputs. It is applied elementwise, i.e., independently to each input in a layer on a single training example.
#
# - With Functional API:
# ```python
# next_layer = layers.LayerNormalization(axis=1)(prev_layer)
# ```
#
# - With Sequential:
# ```python
# model.add(layers.LayerNormalization(axis=1))
# ```

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')

# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# Hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.LayerNormalization(axis=1)(l_1)

# Hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.LayerNormalization(axis=1)(l_2)

# Hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

# Creating Model
model_layer_norm = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_layer_norm')

# %%
model_layer_norm.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_layer_norm = model_layer_norm.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)

# %%
show_loss_accuracy_evolution(history_layer_norm)

# %%
results = model_layer_norm.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# <a id='l1_l2_elasticnet'></a>
# ## L1, L2 and ElasticNet
#
# Recordemos que durante el entrenamiento de la red se aprende la configuración de pesos y biases que permita mejorar los resultados para una determinada función de pérdida.
#
# * [L1 regularization](https://developers.google.com/machine-learning/glossary/#L1_regularization), where the cost added is proportional to the absolute value of the weights coefficients ("L1 norm" of the weights).
#
# ```python
# tf.keras.regularizers.l1(l1=0.01)
#
# layers.Dense(3, kernel_regularizer='l1')
#
# ```
#
#
# * [L2 regularization](https://developers.google.com/machine-learning/glossary/#L2_regularization), where the cost added is proportional to the square of the value of the weights coefficients ( "L2 norm" of the weights).
#
# ```python
# tf.keras.regularizers.l2(l2=0.01)
#
# layers.Dense(3, kernel_regularizer='l2')
#
# ```
# * L1_L2 or Elastic Net.
#
# ```python
# tf.keras.regularizers.l1_l2(
#     l1=0.01, l2=0.01
# )
#
# layers.Dense(3, kernel_regularizer='l1_l2')
#
# ```
#
# Furthermore, it is possible to choose whether to include the penalty in the cost function on the weights, the biases or on the activation, with the following arguments:
# - `kernel_regularizer`: only on weights.
# - `bias_regularizer`: only on biases.
# - `activity_regularizer`: on full output.
#
# [link to documentation](https://keras.io/api/layers/regularizers/).

# %%
from tensorflow.keras import regularizers

# %%
kerner_regularizer_l1 = regularizers.l1_l2(l1=1e-5, l2=5e-4)
kerner_regularizer_l2 = regularizers.l2(5e-4)
kerner_regularizer_l3 = regularizers.l1(1e-5)

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu',
                   kernel_regularizer=
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9901 - loss: 0.1359 - val_accuracy: 0.9000 - val_loss: 0.5815
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9894 - loss: 0.1424 - val_accuracy: 0.9000 - val_loss: 0.5842
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9818 - loss: 0.1472 - val_accuracy: 0.9000 - val_loss: 0.6396
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1110 - val_accuracy: 0.8958 - val_loss: 0.5421
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.1051 - val_accuracy: 0.9042 - val_loss: 0.5210
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.1008 - val_accuracy: 0.9125 - val_loss: 0.5240
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0984 - val_accuracy: 0.9125 - val_loss: 0.5318
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0962 - val_accuracy: 0.9042 - val_loss: 0.5380
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0942 - val_accuracy: 0.9000 - val_loss: 0.5416

# %% [markdown]
# Lets compare the weights norms of the model without regularization and with regularization.

# %%
for ly in model.layers:
    if 'layer_' in ly.name:
        W, b = ly.get_weights()
        l2_norm = np.sum(W**2)**0.5
        zero_elems = len(W[np.abs(W) < 1e-14])
        sparsity = zero_elems / np.prod(W.shape)
        sparsity = np.round(100 * sparsity, 2)
        print('L2 norm {0} weights: {1}, shape:{2}, sparsity:{3}'.format(
            ly.name, l2_norm, W.shape,sparsity))
# Out:
# L2 norm layer_1 weights: 43.37125015258789, shape:(784, 256), sparsity:0.0
# L2 norm layer_2 weights: 23.07696533203125, shape:(256, 128), sparsity:0.0
# L2 norm layer_3 weights: 17.692672729492188, shape:(128, 128), sparsity:0.0

# %%
for ly in model_regularizers.layers:
    if 'layer_' in ly.name:
        W, b = ly.get_weights()
        l2_norm = np.sum(W**2)**0.5
        zero_elems = len(W[np.abs(W) < 1e-14])
        sparsity = zero_elems / np.prod(W.shape)
        sparsity = np.round(100 * sparsity, 2)
        print('L2 norm {0} weights: {1}, shape:{2}, sparsity:{3}'.format(
            ly.name, l2_norm, W.shape,sparsity))
# Out:
# L2 norm layer_1 weights: 8.30661392211914, shape:(784, 256), sparsity:0.0
# L2 norm layer_2 weights: 7.142666339874268, shape:(256, 128), sparsity:4.79
# L2 norm layer_3 weights: 12.364683151245117, shape:(128, 128), sparsity:0.0

# %%
for ly in model_batch_norm.layers:
    if 'layer_' in ly.name:
        W, b = ly.get_weights()
        l2_norm = np.sum(W**2)**0.5
        zero_elems = len(W[np.abs(W) < 1e-14])
        sparsity = zero_elems / np.prod(W.shape)
        sparsity = np.round(100 * sparsity, 2)
        print('L2 norm {0} weights: {1}, shape:{2}, sparsity:{3}'.format(
            ly.name, l2_norm, W.shape,sparsity))
# Out:
# L2 norm layer_1 weights: 19.958812713623047, shape:(784, 256), sparsity:0.0
# L2 norm layer_2 weights: 13.156801223754883, shape:(256, 128), sparsity:0.0
# L2 norm layer_3 weights: 12.208738327026367, shape:(128, 128), sparsity:0.0

# %%
show_loss_accuracy_evolution(history_regularizers)

# %%
results = model_regularizers.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.4775816798210144
# Test Accuracy: 0.9143000245094299

# %% [markdown]
# ### Question 3:
# #### What happens if you change the regularizers?

# %%
# Input
inputs = tf.keras.Input(shape=(28, 28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu',
                   kernel_regularizer=kerner_regularizer_l2, name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu',
                   kernel_regularizer=kerner_regularizer_l2, name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu',
                   kernel_regularizer=kerner_regularizer_l2, name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)


model_regularizers_l2 = keras.Model(inputs=inputs,
                                 outputs=outputs,
                                 name='dont_overfit_model_regularizers_l2')

# %%
model_regularizers_l2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_regularizers_l2 = model_regularizers_l2.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3710 - loss: 2.3629 - val_accuracy: 0.7542 - val_loss: 1.3215
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8037 - loss: 1.0935 - val_accuracy: 0.8583 - val_loss: 0.7808
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8805 - loss: 0.6591 - val_accuracy: 0.8542 - val_loss: 0.7439
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9272 - loss: 0.4973 - val_accuracy: 0.8500 - val_loss: 0.7743
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9588 - loss: 0.4429 - val_accuracy: 0.8708 - val_loss: 0.7231
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9614 - loss: 0.3958 - val_accuracy: 0.8708 - val_loss: 0.6936
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9643 - loss: 0.3843 - val_accuracy: 0.8708 - val_loss: 0.6800
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9734 - loss: 0.3456 - val_accuracy: 0.8917 - val_loss: 0.6188
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9834 - loss: 0.3168 - val_accuracy: 0.8917 - val_loss: 0.6712
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9822 - loss: 0.3062 - val_accuracy: 0.8875 - val_loss: 0.6439
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9881 - loss: 0.2897 - val_accuracy: 0.8833 - val_loss: 0.6615
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9920 - loss: 0.2740 - val_accuracy: 0.8958 - val_loss: 0.6260
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1018 - val_accuracy: 0.8917 - val_loss: 0.5473
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.1001 - val_accuracy: 0.8917 - val_loss: 0.5461
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0985 - val_accuracy: 0.8875 - val_loss: 0.5417
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0969 - val_accuracy: 0.8875 - val_loss: 0.5392
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0954 - val_accuracy: 0.8875 - val_loss: 0.5361
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0938 - val_accuracy: 0.8875 - val_loss: 0.5331
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0923 - val_accuracy: 0.8917 - val_loss: 0.5304
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0909 - val_accuracy: 0.8875 - val_loss: 0.5269
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0895 - val_accuracy: 0.8875 - val_loss: 0.5236
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0881 - val_accuracy: 0.8875 - val_loss: 0.5203
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0867 - val_accuracy: 0.8875 - val_loss: 0.5164
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 0.0854 - val_accuracy: 0.8875 - val_loss: 0.5139
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0841 - val_accuracy: 0.8875 - val_loss: 0.5122
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0829 - val_accuracy: 0.8875 - val_loss: 0.5108
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0816 - val_accuracy: 0.8917 - val_loss: 0.5080
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0805 - val_accuracy: 0.8875 - val_loss: 0.5046
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0793 - val_accuracy: 0.8875 - val_loss: 0.5064
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0782 - val_accuracy: 0.8833 - val_loss: 0.5058
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0771 - val_accuracy: 0.8833 - val_loss: 0.5153
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0762 - val_accuracy: 0.8875 - val_loss: 0.5086
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0751 - val_accuracy: 0.8833 - val_loss: 0.5257
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0743 - val_accuracy: 0.8917 - val_loss: 0.5123
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0734 - val_accuracy: 0.8833 - val_loss: 0.5386
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0724 - val_accuracy: 0.8875 - val_loss: 0.5457
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0719 - val_accuracy: 0.8833 - val_loss: 0.5566
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0711 - val_accuracy: 0.8875 - val_loss: 0.5888
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9981 - loss: 0.0767 - val_accuracy: 0.8208 - val_loss: 0.9051
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9173 - loss: 0.4274 - val_accuracy: 0.8792 - val_loss: 0.5841
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9659 - loss: 0.2020 - val_accuracy: 0.8750 - val_loss: 0.6623
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9591 - loss: 0.1963 - val_accuracy: 0.8667 - val_loss: 0.7016
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9793 - loss: 0.1715 - val_accuracy: 0.8708 - val_loss: 0.7557
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9841 - loss: 0.1623 - val_accuracy: 0.9083 - val_loss: 0.5700
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9845 - loss: 0.1429 - val_accuracy: 0.9250 - val_loss: 0.5466
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9949 - loss: 0.1213 - val_accuracy: 0.8708 - val_loss: 0.6509
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9844 - loss: 0.1793 - val_accuracy: 0.8875 - val_loss: 0.5489
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9962 - loss: 0.1168 - val_accuracy: 0.9083 - val_loss: 0.5003
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9982 - loss: 0.1104 - val_accuracy: 0.9000 - val_loss: 0.5396
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1025 - val_accuracy: 0.9000 - val_loss: 0.5025

# %%
show_loss_accuracy_evolution(history_regularizers_l2)

# %%
results = model_regularizers_l2.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.48488691449165344
# Test Accuracy: 0.9139000177383423

# %% [markdown]
# ## Combine L2 Regularization, Dropout, LN BN
#
# Use L2:
# ```python
# kerner_regularizer_l2 = regularizers.l2(5e-4)
# ```
# And Dropout:
#
# ```python
# next_layer = layers.Dropout(0.4)(prev_layer)
# ```

# %%
kerner_regularizer_l2 = regularizers.l2(5e-4)

# %%
inputs = tf.keras.Input(shape=(28, 28 ), name='input_layer')

# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

flat = layers.Dropout(0.4, name='dropout_flat')(flat)

# Add L2-normalization layer_1
l_1 = layers.Dense(128, activation='relu',
                   kernel_regularizer=kerner_regularizer_l2,
                   name='layer_1')(flat)
l_1 = layers.LayerNormalization(axis=1)(l_1)
l_1 = layers.BatchNormalization()(l_1)
# Add dropout layer_1
l_1 = layers.Dropout(0.4, name='dropout_l1')(l_1)

# Add L2-normalization layer_2
l_2 = layers.Dense(64,
                   activation='relu',
                   kernel_regularizer=kerner_regularizer_l2,
                   name='layer_2')(l_1)

l_2 = layers.LayerNormalization(axis=1)(l_2)
l_2 = layers.BatchNormalization()(l_2)
# Add dropout layer_2
l_2 = layers.Dropout(0.4, name='dropout_l2')(l_2)

# Add L2-normalization layer_3
l_3 = layers.Dense(32,
                   activation='relu',
                   kernel_regularizer=kerner_regularizer_l2,
                   name='layer_3')(l_2)
l_3 = layers.LayerNormalization(axis=1)(l_3)
l_3 = layers.BatchNormalization()(l_3)

# Add dropout
l_3 = layers.Dropout(0.4, name='dropout_l3')(l_3)


outputs = layers.Dense(num_classes, activation='softmax',
                       name='output_layer')(l_3)

model_combination = keras.Model(inputs=inputs,
                                 outputs=outputs,
                                 name='dont_overfit_model_regularizers')

# %%
model_combination.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']
)

# %%
history_combination = model_combination.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.1034 - loss: 3.3594 - val_accuracy: 0.2917 - val_loss: 2.2062
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1794 - loss: 2.8316 - val_accuracy: 0.4417 - val_loss: 1.6884
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2308 - loss: 2.5205 - val_accuracy: 0.5625 - val_loss: 1.4225
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3056 - loss: 2.2009 - val_accuracy: 0.6375 - val_loss: 1.2624
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3395 - loss: 2.0919 - val_accuracy: 0.7083 - val_loss: 1.1511
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3809 - loss: 1.9255 - val_accuracy: 0.7500 - val_loss: 1.0470
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4283 - loss: 1.8329 - val_accuracy: 0.7958 - val_loss: 0.9697
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4539 - loss: 1.7325 - val_accuracy: 0.8208 - val_loss: 0.9157
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4876 - loss: 1.6324 - val_accuracy: 0.8500 - val_loss: 0.8729
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5199 - loss: 1.5785 - val_accuracy: 0.8542 - val_loss: 0.8311
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5288 - loss: 1.5222 - val_accuracy: 0.8708 - val_loss: 0.7917
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5536 - loss: 1.4562 - val_accuracy: 0.8625 - val_loss: 0.7620
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6131 - loss: 1.3089 - val_accuracy: 0.8542 - val_loss: 0.7395
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5849 - loss: 1.3041 - val_accuracy: 0.8542 - val_loss: 0.7155
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6032 - loss: 1.2859 - val_accuracy: 0.8667 - val_loss: 0.6970
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6239 - loss: 1.2360 - val_accuracy: 0.8750 - val_loss: 0.6727
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6716 - loss: 1.1677 - val_accuracy: 0.8833 - val_loss: 0.6618
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6846 - loss: 1.0949 - val_accuracy: 0.8833 - val_loss: 0.6389
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6803 - loss: 1.1254 - val_accuracy: 0.8833 - val_loss: 0.6233
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6765 - loss: 1.1508 - val_accuracy: 0.8792 - val_loss: 0.6090
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6768 - loss: 1.1007 - val_accuracy: 0.8875 - val_loss: 0.5980
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7143 - loss: 1.0198 - val_accuracy: 0.8833 - val_loss: 0.5867
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7310 - loss: 0.9691 - val_accuracy: 0.9000 - val_loss: 0.5775
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9039 - loss: 0.4035 - val_accuracy: 0.9125 - val_loss: 0.5989

# %%
show_loss_accuracy_evolution(history_combination)

# %%
results = model_combination.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5510221123695374
# Test Accuracy: 0.904699981212616

# %% [markdown]
# ## Noise injection
#
# Apply additive zero-mean Gaussian noise.
#
# With Functional API:
# ```python
# next_layer = layers.GaussianNoise(stddev)(prev_layer)
# ```
# With Sequential:
# ```python
# model.add(layers.GaussianNoise(stddev)())
# ```

# %%
stddev = 2

# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
l_1 = layers.GaussianNoise(stddev, name='noise_l1')(l_1)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
l_2 = layers.GaussianNoise(stddev, name='noise_l2')(l_2)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)
l_3 = layers.GaussianNoise(stddev, name='noise_l3')(l_3)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

model_noise = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_noise')

# %%
model_noise.summary()

# %%
model_noise.compile(
    optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history_noise = model_noise.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True
)

# %%
show_loss_accuracy_evolution(history_noise)

# %%
results = model_noise.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# <a id='early_stopping'></a>
# ## Early Stopping
#
# Another of the most used techniques in neural network training is **early stopping**. It basically consists of stopping the training process in an Epoch prior to the one defined in the compilation.
#
# This, in addition to resulting in a model with less overfitting, saves unnecessary computation time.
#
# To do this, we can use the [Keras callbacks](https://keras.io/api/callbacks/), objects that perform actions at different times during training. Specifically, we will make use of [`EarlyStopping`](https://keras.io/api/callbacks/early_stopping/).
#
# ```python
# tf.keras.callbacks.EarlyStopping(
#     monitor="val_loss",
#     min_delta=0,
#     patience=0,
#     restore_best_weights=True,
#     verbose=0,
# )
# ```
#
# - **monitor**: Quantity to be monitored. Depending on the evolution, it will be decided to stop training.
#
# - **min_delta**: Minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
#
# - **patience**: Number of epochs with no improvement after which training will be stopped.
#
# - **verbose**: verbosity mode.
#
# There are other callbacks that can be very useful such as:
# - [`ModelCheckpoint`](https://keras.io/api/callbacks/model_checkpoint/), which allows storing the state of a model at different times of training. This is very useful in trainings that can take hours or days.
# - [`TensorBoard`](https://keras.io/api/callbacks/tensorboard/), which allows the use of [TensorBoard](https://www.tensorflow.org/tensorboard?hl=es-419), framework TensorFlow for visualizing metrics and evaluating models.

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # can be 'val_accuracy'
    patience=5,  # if during 5 epochs there is no improvement in `val_loss`, the execution will stop
    restore_best_weights=True,
    verbose=1)

# %% [markdown]
# Lets create the same model:

# %%
# Input
inputs = tf.keras.Input(shape=(28,28), name='input_layer')
# Convert the 2D image to a vector
flat = layers.Flatten()(inputs)

# hidden layer 1
l_1 = layers.Dense(256, activation='relu', name='layer_1')(flat)
# hidden layer 2
l_2 = layers.Dense(128, activation='relu', name='layer_2')(l_1)
# hidden layer 3
l_3 = layers.Dense(128, activation='relu', name='layer_3')(l_2)

# Outputs
outputs = layers.Dense(num_classes, activation='softmax', name='output_layer')(l_3)

model_early_stopping = keras.Model(inputs=inputs, outputs=outputs, name='dont_overfit_model_early_stopping')

# %%
model_early_stopping.summary()

# %%
model_early_stopping.compile(optimizer='adam',
                             loss='sparse_categorical_crossentropy',
                             metrics=['accuracy'])

# %%
history_early_stopping = model_early_stopping.fit(
    x,
    y,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
    shuffle=True,
    callbacks=[es_callback]
)

# %%
show_loss_accuracy_evolution(history_early_stopping)

# %%
results = model_early_stopping.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# <a id='tensorboard'></a>
# # TensorBoard
#
#
#
# [TensorBoard](https://www.tensorflow.org/tensorboard) is a set of TensorFlow tools that allows us to represent the evolution and results of the training.
#
# In order to introduce this tool, the following is a notebook from the [TensorFlow tutorial on TensorBoard](https://www.tensorflow.org/tensorboard/get_started).

# %% [markdown]
# Load TensorBoard notebook extension.

# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
import datetime

# %% [markdown]
# We build the model. The input layer will have a dimension of `28x28`. The output layer, in a multiclass classification problem with 10 possible classes, will be made up of 10 neurons with [softmax activation function](https://keras.io/api/layers/activations/#softmax-function ).

# %%
kernel_regularizer_l2 = keras.regularizers.l2(5e-4)

model = tf.keras.models.Sequential(name="tensorboard_model")
model.add(layers.Flatten(input_shape=(28, 28)))

# Hidden Layer + regularization
model.add(layers.Dense(64, activation='relu', name='layer_1'))
model.add(layers.Dense(64, activation='relu',
                       kernel_regularizer=kernel_regularizer_l2, name='layer_2'))
# output layer
model.add(layers.Dense(10, activation='softmax', name='output_layer'))

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# In the [example with early stopping](#early_stopping) the Keras callbacks were presented. To use TensorBoard we will need to include the [`TensorBoard` callback](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard) to the training.
#
# This callback will create and store the logs in the directory that we indicate.
#
# By default it will create a directory called "logs" in the directory where this notebook is running.

# %%
log_dir = 'logs/fit/' + datetime.datetime.now().strftime('%Y%m%d-%H%M%S')

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
es_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',  # can be 'val_accuracy'
    patience=10,  # if during 5 epochs there is no improvement in `val_loss`, the execution will stop
    restore_best_weights=True,
    verbose=1)

# %% [markdown]
# Train the model

# %%
model.fit(
    x=x_train,
    y=y_train,
    epochs=20,
    validation_split=0.2,
    batch_size=32,
    callbacks=[tensorboard_callback, es_callback]
)

# %%
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# To ** start TensorBoard ** we can execute the following cell or, from the command line, execute:
#
#     tensorboard --logdir logs / fit
#
# An application will be launched that will be listening by default on port 6006. It is possible to use TensorBoard by opening [localhost: 6006 /](http://localhost:6006/) in a browser.

# %%
# %tensorboard --logdir logs/fit

# %% [markdown]
# A brief overview of the dashboards shown (tabs in top navigation bar):
#
# * The **Scalars** dashboard shows how the loss and metrics change with every epoch. You can use it to also track training speed, learning rate, and other scalar values.
# * The **Graphs** dashboard helps you visualize your model. In this case, the Keras graph of layers is shown which can help you ensure it is built correctly.
# * The **Distributions** and **Histograms** dashboards show the distribution of a Tensor over time. This can be useful to visualize weights and biases and verify that they are changing in an expected way.

# %% [markdown]
# ### Improve the last model with some regularization techniques to obtain at least `0.98` of test accuracy

# %%
model = tf.keras.models.Sequential()
model.add(layers.Flatten(input_shape=(28, 28)))

## Hidden Layer + regularization
model.add(...)
### output layer
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    x=x_train,
    y=y_train,
    epochs=5,
    validation_split=0.2,
    batch_size=64
)
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %%
model.fit(
    x=x_train,
    y=y_train,
    epochs=...,
    validation_split=0.2,
    batch_size=...,
    callbacks=...
)
results = model.evaluate(x_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))

# %% [markdown]
# ### Plotting Predictions

# %%
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, -1)

# %%
L = 5
W = 5
fig, axes = plt.subplots(L, W, figsize=(14, 14))
axes = axes.ravel()

for i in np.arange(0, L * W):
    ind = np.random.randint(len(y_test))
    axes[i].imshow(x_test[ind].reshape(28, 28))
    prob_pred = np.max(predictions[ind, :])
    class_pred = int(predicted_classes[ind])
    original_class = int(y_test[ind])
    if class_pred == original_class:
        color = 'green'
    else:
        color = 'red'
    title = "Pred: {0} \n Target: {1} \n Prob: {2:.3f}".format(
    class_pred, original_class, prob_pred)
    axes[i].set_title(title, color=color)
    axes[i].axis('off')

plt.subplots_adjust(wspace=0.5)
