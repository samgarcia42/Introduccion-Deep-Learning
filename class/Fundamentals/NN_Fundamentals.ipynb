# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

tf.random.set_seed(0)

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
    h = 0.05
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[:,0], X[:,1], c=y.ravel(), cmap=plt.cm.Spectral)

def load_planar_dataset(m, sigma=0.2):
    N = int(m/2) # number of points per class
    D = 2 # dimensionality
    X = np.zeros((m,D)) # data matrix where each row is a single example
    Y = np.zeros((m,1), dtype='uint8') # labels vector (0 for red, 1 for blue)
    a = 4 # maximum ray of the flower

    for j in range(2):
        ix = range(N*j,N*(j+1))
        t = np.linspace(j*3.12,(j+1)*3.12,N) + np.random.randn(N)*sigma # theta
        r = a*np.sin(4*t) + np.random.randn(N)*sigma # radius
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        Y[ix] = j

    ## premuting ouput
    p = np.random.permutation(m)
    X = X[p,:]
    Y = Y[p,:]

    return X, Y.ravel()

def draw_neural_net(left, right, bottom, top, layer_sizes):
    '''
    From https://gist.github.com/craffel/2d727968c3aaebd10359#file-draw_neural_net-py
    Draw a neural network cartoon using matplotilb.

    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])

    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    fig = plt.figure(figsize=(3, 3))
    ax = fig.gca()
    ax.axis('off')

    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                ax.add_artist(line)

# %% [markdown]
# ## Dataset
#
# We have a binary classification dataset. The target `y` has two possible values, {0,1} and the input vector `x` has two dimensions.

# %%
N = 5000
X, y = load_planar_dataset(N, 0.2)

# %% [markdown]
# Visualize the dataset using matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data.

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.2,
)

# %%
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(4000, 2), y_train shape:(4000,)
# X_test shape:(1000, 2), y_test shape:(1000,)

# %%
## X first example
X[0,:]
# Out:
# array([ 3.4030781 , -0.96761649])

# %%
## Y firsts examples
y[:8]
# Out:
# array([0, 1, 1, 0, 0, 0, 0, 0], dtype=uint8)

# %% [markdown]
# ## First NN in Keras
#
# ### Logistic regression
#
# Fully connected layers are defined using the [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) class. We can specify the number of neurons as the first argument, and specify the activation function using the activation argument.
#
# ```python
# tf.keras.layers.Dense(
#     units, activation=None
# )
#
# ```
#
# - **units**: Number of neurons in the layer.
# - **activation**: Activation function to use, default function is `linear`, you can also use `sigmoid` for sigmoid activation or [other alternatives](https://www.tensorflow.org/api_docs/python/tf/keras/activations)
#
# For defining the input layer you can use `keras.Input(shape=(input_dimension,))` or define your input dimension in the first hidden layer.
#
# ```python
# layers.Dense(4, activation="sigmoid", input_shape=(input_dimension,))
#
# ```
#
# Build a network without hidden layer

# %%
draw_neural_net(.1, .9, .1, .9, [2, 1])

# %%
model = keras.Sequential()
# The dimension of the input is 2 (planar data)
# we have only one output layer with 1 neuron
model.add(keras.layers.Dense(1, input_shape=(2, ), activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# #### Compile
# Now we need to specify the loss function, the metrics and the optimizer. It is done using compile function in Keras.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #### Training model
# This is similar to a sklearn model.

# %%
model.fit(X_train, y_train, epochs=10,
          validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6402 - loss: 0.7220 - val_accuracy: 0.6425 - val_loss: 0.7413
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6795 - loss: 0.6977 - val_accuracy: 0.6550 - val_loss: 0.7175
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6815 - loss: 0.6818 - val_accuracy: 0.6300 - val_loss: 0.7010
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6419 - loss: 0.6720 - val_accuracy: 0.5788 - val_loss: 0.6901
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5922 - loss: 0.6662 - val_accuracy: 0.5437 - val_loss: 0.6830
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5573 - loss: 0.6632 - val_accuracy: 0.5200 - val_loss: 0.6787
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5277 - loss: 0.6618 - val_accuracy: 0.4925 - val_loss: 0.6760
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4980 - loss: 0.6612 - val_accuracy: 0.4762 - val_loss: 0.6744
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4714 - loss: 0.6610 - val_accuracy: 0.4688 - val_loss: 0.6734
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4636 - loss: 0.6610 - val_accuracy: 0.4700 - val_loss: 0.6727

# %% [markdown]
# #### Making predictions

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6521173119544983
# Test Accuracy: 0.4950000047683716

# %%
y_pred = model.predict(X_test)
y_pred[:3], y_test[:3]
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# (array([[0.4982713 ],
#         [0.49594632],
#         [0.44995147]], dtype=float32),
#  array([1, 1, 1], dtype=uint8))

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("Basic NN");
# Out:
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### One hidden layer NN
#
# - One **input with 2 features (input_shape)**
# - **One hidden dense layer**,  with **3 neurons** and implemented with  **sigmoid activating function**
# - **One Output** (sigmoid output activation function)
#
# We can create layers incrementally with the method `add()`:

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 1])

# %%
model = keras.Sequential()

## hidden layer with 3 neurons and sigmoid activation
## The first layer need to have the input_shape
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

## model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# You can also define the model with a list of layers
# ```python
# model = keras.Sequential([
#     keras.Input(shape=(2, )),
#     layers.Dense(3, activation='sigmoid', name='layer1'),
#     layers.Dense(1, activation='sigmoid', name='layer3')
# ])
# ````

# %%
plot_model(model, show_shapes=True)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4975 - loss: 0.8255 - val_accuracy: 0.4800 - val_loss: 0.8129
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4910 - loss: 0.7698 - val_accuracy: 0.4288 - val_loss: 0.7652
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4443 - loss: 0.7323 - val_accuracy: 0.4475 - val_loss: 0.7336
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5044 - loss: 0.7081 - val_accuracy: 0.5250 - val_loss: 0.7133
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5708 - loss: 0.6927 - val_accuracy: 0.5450 - val_loss: 0.7001
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5854 - loss: 0.6827 - val_accuracy: 0.5938 - val_loss: 0.6913
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6292 - loss: 0.6756 - val_accuracy: 0.6313 - val_loss: 0.6847
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6541 - loss: 0.6699 - val_accuracy: 0.6450 - val_loss: 0.6793
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6676 - loss: 0.6648 - val_accuracy: 0.6425 - val_loss: 0.6744
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6586 - loss: 0.6600 - val_accuracy: 0.6338 - val_loss: 0.6697
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6551 - loss: 0.6551 - val_accuracy: 0.6275 - val_loss: 0.6651
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6496 - loss: 0.6502 - val_accuracy: 0.6263 - val_loss: 0.6604
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6436 - loss: 0.6452 - val_accuracy: 0.6225 - val_loss: 0.6557
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6444 - loss: 0.6402 - val_accuracy: 0.6200 - val_loss: 0.6511
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6460 - loss: 0.6352 - val_accuracy: 0.6187 - val_loss: 0.6464
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6460 - loss: 0.6303 - val_accuracy: 0.6187 - val_loss: 0.6418
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6463 - loss: 0.6255 - val_accuracy: 0.6187 - val_loss: 0.6374
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6460 - loss: 0.6209 - val_accuracy: 0.6175 - val_loss: 0.6331
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6462 - loss: 0.6165 - val_accuracy: 0.6175 - val_loss: 0.6289
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6462 - loss: 0.6123 - val_accuracy: 0.6175 - val_loss: 0.6250
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6459 - loss: 0.6084 - val_accuracy: 0.6175 - val_loss: 0.6213
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6455 - loss: 0.6047 - val_accuracy: 0.6162 - val_loss: 0.6177
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6458 - loss: 0.6012 - val_accuracy: 0.6162 - val_loss: 0.6144
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6450 - loss: 0.5979 - val_accuracy: 0.6162 - val_loss: 0.6113
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6446 - loss: 0.5949 - val_accuracy: 0.6137 - val_loss: 0.6083

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.5860495567321777
# Test Accuracy: 0.6600000262260437

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN");
# Out:
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### Question 1:
# ####  What happens if we change the activation function of the first hidden  layer to `'linear'`?

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='linear'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4945 - loss: 1.7302 - val_accuracy: 0.4800 - val_loss: 1.6128
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4995 - loss: 1.3934 - val_accuracy: 0.5038 - val_loss: 1.3279
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5229 - loss: 1.1520 - val_accuracy: 0.5213 - val_loss: 1.1221
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5537 - loss: 0.9829 - val_accuracy: 0.5425 - val_loss: 0.9754
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5752 - loss: 0.8663 - val_accuracy: 0.5763 - val_loss: 0.8724
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6130 - loss: 0.7875 - val_accuracy: 0.6288 - val_loss: 0.8013
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6553 - loss: 0.7356 - val_accuracy: 0.6488 - val_loss: 0.7533
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6719 - loss: 0.7025 - val_accuracy: 0.6500 - val_loss: 0.7216
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6684 - loss: 0.6825 - val_accuracy: 0.6125 - val_loss: 0.7014
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6178 - loss: 0.6712 - val_accuracy: 0.5562 - val_loss: 0.6890
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5728 - loss: 0.6653 - val_accuracy: 0.5250 - val_loss: 0.6817
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5358 - loss: 0.6625 - val_accuracy: 0.4963 - val_loss: 0.6774
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5006 - loss: 0.6614 - val_accuracy: 0.4737 - val_loss: 0.6750
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4744 - loss: 0.6611 - val_accuracy: 0.4725 - val_loss: 0.6737
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4684 - loss: 0.6611 - val_accuracy: 0.4737 - val_loss: 0.6729
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4652 - loss: 0.6612 - val_accuracy: 0.4737 - val_loss: 0.6724
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4657 - loss: 0.6612 - val_accuracy: 0.4712 - val_loss: 0.6722
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4656 - loss: 0.6613 - val_accuracy: 0.4712 - val_loss: 0.6720
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4639 - loss: 0.6613 - val_accuracy: 0.4712 - val_loss: 0.6720
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4650 - loss: 0.6614 - val_accuracy: 0.4712 - val_loss: 0.6719
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4650 - loss: 0.6614 - val_accuracy: 0.4712 - val_loss: 0.6719
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4650 - loss: 0.6614 - val_accuracy: 0.4712 - val_loss: 0.6719
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4650 - loss: 0.6614 - val_accuracy: 0.4712 - val_loss: 0.6719
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4649 - loss: 0.6614 - val_accuracy: 0.4712 - val_loss: 0.6719
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4649 - loss: 0.6614 - val_accuracy: 0.4725 - val_loss: 0.6719

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.6518176794052124
# Test Accuracy: 0.49000000953674316
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### Question 2:
# ####  What happens if we add more neurons to the first hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 5, 1])

# %%
model = keras.Sequential()

## The first layer need to have the input_shape
## set the number of neurons
model.add(layers.Dense(5, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6126 - loss: 0.6674 - val_accuracy: 0.6075 - val_loss: 0.6518
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5997 - loss: 0.6453 - val_accuracy: 0.4975 - val_loss: 0.6440
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5206 - loss: 0.6361 - val_accuracy: 0.5000 - val_loss: 0.6391
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5215 - loss: 0.6299 - val_accuracy: 0.5038 - val_loss: 0.6346
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5141 - loss: 0.6245 - val_accuracy: 0.5075 - val_loss: 0.6302
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5163 - loss: 0.6196 - val_accuracy: 0.5125 - val_loss: 0.6260
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5198 - loss: 0.6150 - val_accuracy: 0.5138 - val_loss: 0.6219
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5216 - loss: 0.6107 - val_accuracy: 0.5150 - val_loss: 0.6181
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5223 - loss: 0.6068 - val_accuracy: 0.5150 - val_loss: 0.6145
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5247 - loss: 0.6031 - val_accuracy: 0.5163 - val_loss: 0.6112
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5271 - loss: 0.5997 - val_accuracy: 0.5163 - val_loss: 0.6081
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5358 - loss: 0.5965 - val_accuracy: 0.5188 - val_loss: 0.6052
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5342 - loss: 0.5936 - val_accuracy: 0.5225 - val_loss: 0.6026
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5339 - loss: 0.5909 - val_accuracy: 0.5312 - val_loss: 0.6002
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5345 - loss: 0.5885 - val_accuracy: 0.5325 - val_loss: 0.5980
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5415 - loss: 0.5862 - val_accuracy: 0.5412 - val_loss: 0.5960
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5430 - loss: 0.5842 - val_accuracy: 0.5500 - val_loss: 0.5941
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5487 - loss: 0.5823 - val_accuracy: 0.5625 - val_loss: 0.5925
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5571 - loss: 0.5806 - val_accuracy: 0.5650 - val_loss: 0.5910
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5599 - loss: 0.5791 - val_accuracy: 0.5713 - val_loss: 0.5896
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5654 - loss: 0.5777 - val_accuracy: 0.5725 - val_loss: 0.5884
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5700 - loss: 0.5764 - val_accuracy: 0.5775 - val_loss: 0.5873
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5739 - loss: 0.5752 - val_accuracy: 0.5813 - val_loss: 0.5862
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5769 - loss: 0.5741 - val_accuracy: 0.5850 - val_loss: 0.5853
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5803 - loss: 0.5731 - val_accuracy: 0.5863 - val_loss: 0.5845

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5605594515800476
# Test Accuracy: 0.6079999804496765
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### Question 3:
# ####  What happens if we add one more hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 3, 1])

# %%
model = keras.Sequential()
# First hidden layer (need to innclude input_shape)
## Set the number of neurons
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# second hidden layer
## Complete the code
### "input_shape" solo de coloca en la primera capa oculta
model.add(layers.Dense(3, activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5025 - loss: 0.7130 - val_accuracy: 0.5200 - val_loss: 0.6916
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5025 - loss: 0.6938 - val_accuracy: 0.5200 - val_loss: 0.6863
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5109 - loss: 0.6878 - val_accuracy: 0.6275 - val_loss: 0.6843
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6186 - loss: 0.6850 - val_accuracy: 0.6800 - val_loss: 0.6823
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6558 - loss: 0.6828 - val_accuracy: 0.6950 - val_loss: 0.6801
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6632 - loss: 0.6805 - val_accuracy: 0.6900 - val_loss: 0.6775
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6689 - loss: 0.6780 - val_accuracy: 0.6913 - val_loss: 0.6746
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6691 - loss: 0.6749 - val_accuracy: 0.6938 - val_loss: 0.6710
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6653 - loss: 0.6712 - val_accuracy: 0.6925 - val_loss: 0.6669
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6574 - loss: 0.6669 - val_accuracy: 0.6812 - val_loss: 0.6622
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6551 - loss: 0.6621 - val_accuracy: 0.6762 - val_loss: 0.6572
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6500 - loss: 0.6570 - val_accuracy: 0.6762 - val_loss: 0.6518
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6489 - loss: 0.6516 - val_accuracy: 0.6737 - val_loss: 0.6464
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6472 - loss: 0.6462 - val_accuracy: 0.6712 - val_loss: 0.6409
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6468 - loss: 0.6408 - val_accuracy: 0.6712 - val_loss: 0.6356
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6472 - loss: 0.6355 - val_accuracy: 0.6700 - val_loss: 0.6304
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6472 - loss: 0.6304 - val_accuracy: 0.6700 - val_loss: 0.6255
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6468 - loss: 0.6255 - val_accuracy: 0.6700 - val_loss: 0.6208
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6462 - loss: 0.6208 - val_accuracy: 0.6700 - val_loss: 0.6164
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6464 - loss: 0.6164 - val_accuracy: 0.6700 - val_loss: 0.6122
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6463 - loss: 0.6122 - val_accuracy: 0.6700 - val_loss: 0.6084
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6443 - loss: 0.6082 - val_accuracy: 0.6700 - val_loss: 0.6048
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6443 - loss: 0.6044 - val_accuracy: 0.6700 - val_loss: 0.6014
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6436 - loss: 0.6008 - val_accuracy: 0.6700 - val_loss: 0.5983
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6433 - loss: 0.5974 - val_accuracy: 0.6687 - val_loss: 0.5954

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5858147144317627
# Test Accuracy: 0.6549999713897705
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ####  Use  the [hyperbolic tangent](https://mathworld.wolfram.com/HyperbolicTangent.html) activation `'tanh'` with the first simple model and compare the results with the sigmoid activation

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='tanh'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5105 - loss: 0.7942 - val_accuracy: 0.5275 - val_loss: 0.7430
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5201 - loss: 0.7565 - val_accuracy: 0.5362 - val_loss: 0.7182
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5332 - loss: 0.7308 - val_accuracy: 0.5612 - val_loss: 0.6986
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5790 - loss: 0.7090 - val_accuracy: 0.6475 - val_loss: 0.6781
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6592 - loss: 0.6838 - val_accuracy: 0.7000 - val_loss: 0.6503
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6742 - loss: 0.6519 - val_accuracy: 0.6825 - val_loss: 0.6270
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6486 - loss: 0.6277 - val_accuracy: 0.6662 - val_loss: 0.6142
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6417 - loss: 0.6136 - val_accuracy: 0.6575 - val_loss: 0.6061
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6353 - loss: 0.6040 - val_accuracy: 0.6525 - val_loss: 0.5999
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6309 - loss: 0.5964 - val_accuracy: 0.6463 - val_loss: 0.5947
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6254 - loss: 0.5901 - val_accuracy: 0.6375 - val_loss: 0.5904
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6159 - loss: 0.5849 - val_accuracy: 0.6300 - val_loss: 0.5868
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6016 - loss: 0.5804 - val_accuracy: 0.6200 - val_loss: 0.5838
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5934 - loss: 0.5767 - val_accuracy: 0.6087 - val_loss: 0.5814
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5845 - loss: 0.5736 - val_accuracy: 0.6075 - val_loss: 0.5794
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5851 - loss: 0.5710 - val_accuracy: 0.6037 - val_loss: 0.5777
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5788 - loss: 0.5688 - val_accuracy: 0.5962 - val_loss: 0.5762
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5765 - loss: 0.5669 - val_accuracy: 0.5913 - val_loss: 0.5750
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5739 - loss: 0.5653 - val_accuracy: 0.5763 - val_loss: 0.5740
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5623 - loss: 0.5640 - val_accuracy: 0.5525 - val_loss: 0.5731
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5466 - loss: 0.5628 - val_accuracy: 0.5412 - val_loss: 0.5724
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5719 - loss: 0.5617 - val_accuracy: 0.5738 - val_loss: 0.5717
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5969 - loss: 0.5608 - val_accuracy: 0.5825 - val_loss: 0.5712
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6038 - loss: 0.5600 - val_accuracy: 0.5900 - val_loss: 0.5706
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6066 - loss: 0.5593 - val_accuracy: 0.5900 - val_loss: 0.5702

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5489324927330017
# Test Accuracy: 0.6269999742507935
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ## Practice I
#
# Repeat the process with a different dataset.

# %%
N = 5000
X, y = sklearn.datasets.make_moons(n_samples=N, noise=.18)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(3750, 2), y_train shape:(3750,)
# X_test shape:(1250, 2), y_test shape:(1250,)

# %% [markdown]
# ### Define your model

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers.Dense(8, input_shape=(2,), activation='tanh'))

## Second Layer, don't use input_shape
model.add(layers.Dense(8, activation='tanh'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4724 - loss: 0.7026 - val_accuracy: 0.8747 - val_loss: 0.5578
# Epoch 2/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8823 - loss: 0.5125 - val_accuracy: 0.8693 - val_loss: 0.4298
# Epoch 3/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8724 - loss: 0.3971 - val_accuracy: 0.8640 - val_loss: 0.3655
# Epoch 4/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8741 - loss: 0.3383 - val_accuracy: 0.8680 - val_loss: 0.3357
# Epoch 5/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8736 - loss: 0.3093 - val_accuracy: 0.8667 - val_loss: 0.3216
# Epoch 6/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8710 - loss: 0.2944 - val_accuracy: 0.8667 - val_loss: 0.3147
# Epoch 7/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8704 - loss: 0.2863 - val_accuracy: 0.8707 - val_loss: 0.3112
# Epoch 8/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8718 - loss: 0.2817 - val_accuracy: 0.8707 - val_loss: 0.3095
# Epoch 9/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8742 - loss: 0.2791 - val_accuracy: 0.8720 - val_loss: 0.3086
# Epoch 10/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8739 - loss: 0.2776 - val_accuracy: 0.8720 - val_loss: 0.3080
# Epoch 11/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8729 - loss: 0.2766 - val_accuracy: 0.8707 - val_loss: 0.3077
# Epoch 12/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8724 - loss: 0.2759 - val_accuracy: 0.8707 - val_loss: 0.3074
# Epoch 13/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8730 - loss: 0.2754 - val_accuracy: 0.8707 - val_loss: 0.3072
# Epoch 14/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8730 - loss: 0.2750 - val_accuracy: 0.8707 - val_loss: 0.3069
# Epoch 15/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2747 - val_accuracy: 0.8707 - val_loss: 0.3066
# Epoch 16/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2743 - val_accuracy: 0.8707 - val_loss: 0.3063
# Epoch 17/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8729 - loss: 0.2740 - val_accuracy: 0.8707 - val_loss: 0.3061
# Epoch 18/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2738 - val_accuracy: 0.8707 - val_loss: 0.3058
# Epoch 19/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2735 - val_accuracy: 0.8707 - val_loss: 0.3055
# Epoch 20/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2732 - val_accuracy: 0.8707 - val_loss: 0.3052
# Epoch 21/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2730 - val_accuracy: 0.8707 - val_loss: 0.3050
# Epoch 22/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2727 - val_accuracy: 0.8707 - val_loss: 0.3047
# Epoch 23/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2725 - val_accuracy: 0.8707 - val_loss: 0.3045
# Epoch 24/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.2723 - val_accuracy: 0.8707 - val_loss: 0.3042
# Epoch 25/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.2720 - val_accuracy: 0.8707 - val_loss: 0.3040
# Epoch 26/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.2718 - val_accuracy: 0.8707 - val_loss: 0.3037
# Epoch 27/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.2716 - val_accuracy: 0.8707 - val_loss: 0.3035
# Epoch 28/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8732 - loss: 0.2714 - val_accuracy: 0.8707 - val_loss: 0.3032
# Epoch 29/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.2711 - val_accuracy: 0.8707 - val_loss: 0.3030
# Epoch 30/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.2709 - val_accuracy: 0.8707 - val_loss: 0.3027
# Epoch 31/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.2707 - val_accuracy: 0.8707 - val_loss: 0.3025
# Epoch 32/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.2704 - val_accuracy: 0.8707 - val_loss: 0.3022
# Epoch 33/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8741 - loss: 0.2702 - val_accuracy: 0.8720 - val_loss: 0.3019
# Epoch 34/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8741 - loss: 0.2699 - val_accuracy: 0.8720 - val_loss: 0.3017
# Epoch 35/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8741 - loss: 0.2697 - val_accuracy: 0.8720 - val_loss: 0.3014

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.2846705913543701
# Test Accuracy: 0.871999979019165
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Saving and Loading Keras Models
#
# You can easily save your entire model (architecture, weights, and optimizer state) in a single call using either `.keras` or `.h5` formats.
#
# - **`.keras`**: The default and recommended format from TensorFlow 2.12 onwards. It includes comprehensive model metadata and is future-proof.
# - **`.h5`**: An older HDF5 format that is still widely used due to its simplicity and compatibility.

# %%
import datetime

# Save model with timestamp
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
model_name_keras = f"keras_model_{current_time}.keras"
#model_name_h5 = f"keras_model_{current_time}.h5"

# Save in .keras format (recommended for TensorFlow/Keras > 2.12)
model.save(model_name_keras)

# Alternatively, save in .h5 format
#model.save(model_name_h5)

print(f"Models saved as: {model_name_keras}")
# Out:
# Models saved as: keras_model_20250519-050139.keras

# %%
# List files in current directory
# !ls -l
# Out:
# total 64
# -rw-r--r-- 1 root root 26669 May 19 05:01 keras_model_20250519-050139.keras
# -rw-r--r-- 1 root root 30749 May 19 02:26 model.png
# drwxr-xr-x 1 root root  4096 May 14 13:38 sample_data

# %%
from tensorflow.keras.models import load_model

# Load your previously saved model
loaded_model = load_model(model_name_keras)  # or .h5

# Evaluate loaded model
loss, accuracy = loaded_model.evaluate(X_test, y_test)
print(f"Loaded model accuracy: {accuracy*100:.2f}%")

# %% [markdown]
# ### Question 4: Train 10 epochs, save the model, load it, and then train 10 more epochs

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers...(..., input_shape=(...,), activation=...))

## Second Layer, don't use input_shape
model...(...)

# output layer
model.add(layers.Dense(..., activation=...))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=..., validation_split=0.2, batch_size=64)

# %%
# Save the model
model_name = ...
model.save(...

# %%
# load the model

# %%
# Train the model 10 more epochs
model.fit(X_train, y_train, epochs=..., validation_split=0.2, batch_size=64)

# %% [markdown]
# ## Functional API
#
# The Keras Functional API allows defining the topology of the models as a [acyclic directed graph](https://en.wikipedia.org/wiki/Directed_acyclic_graph) of layers. Next we will build the same model as in the previous section but using the Keras Functional API.
#
# You need to start with an input data entry:
# ```python
#     inputs = keras.Input(shape=(8,))
# ```
#
# We define the layers that we will include in the network and the relationships between them. It is important to note that each line details the type of layer and its properties (number of neurons, activation function, name ...) and just at the end, in parentheses, the name of the variable in which we have saved the layer from which its output will connect to the input of the layer we are declaring.
# ```python
# layer_1 = layers.Dense(4, activation='sigmoid',
#                        name='layer_1')(inputs)
# layer_2 = layers.Dense(4, activation='sigmoid',
#                        name='layer_2')(layer_1)
# ```
#
# The "layer call" `Dense()(inputs)` action is like drawing an arrow from "inputs" to this layer you created. You're "passing" the inputs to the dense layer, and you get `layer_1` as the output.
#
#
#
# Finally, we define the network outputs:
# ```python
# outputs = layers.Dense(1, name='output_layer')(layer_2)
# ```
#
# We create the model specifying the inputs and outputs:
# ```python
# model = keras.Model(inputs=inputs, outputs=outputs)
# ```

# %%
draw_neural_net(.1, .9, .1, .9, [8, 4, 4, 1])

# %%
inputs = keras.Input(shape=(8, ), name='input_layer')
l_1 = layers.Dense(4, activation='relu', name='layer_1')(inputs)
l_2 = layers.Dense(4, activation='relu', name='layer_2')(l_1)
outputs = layers.Dense(1, activation="sigmoid", name='output_layer')(l_2)

model = keras.Model(inputs=inputs, outputs=outputs, name='example_model')

model.summary()

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ## Practice II
#
# Repeat the process with a different dataset and the **Functional API**

# %%
N = 5000
X, y = sklearn.datasets.make_circles(n_samples=N, factor=.65, noise=.065) # sklearn.datasets.make_moons(n_samples=N, noise=.15)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))

# %% [markdown]
# ### Define your model

# %%
inputs = keras.Input(shape=(2, ), name='input_layer')
## First hidden layer
l_1 = layers.Dense(...)(inputs)
...

## output layer
outputs = layers.Dense(...


model = keras.Model(inputs=inputs,...

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)

# %% [markdown]
# ## Visualize decision boundary by epoch

# %%
from sklearn.preprocessing import StandardScaler
from IPython.display import Image
import os

# %%
def plot_save_decision_boundary(model, X, y, epoch, epoch_image):
    h = 0.1
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    X_grid = np.c_[xx.ravel(), yy.ravel()]
    Z = model.predict(X_grid)
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.5, colors=['blue', 'red'], levels=[-0.5, 0.5, 1.5])
    plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0', alpha=0.5)
    plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1', alpha=0.5)
    plt.title(f'Epoch {epoch}')
    plt.savefig(epoch_image)
    plt.close()

def generate_spiral_dataset(n_points, noise=0.5):
    n = np.sqrt(np.random.rand(n_points, 1)) * 780 * (2 * np.pi) / 360
    d1x = -np.cos(n) * n + np.random.rand(n_points, 1) * noise
    d1y = np.sin(n) * n + np.random.rand(n_points, 1) * noise

    X, y = (np.vstack((np.hstack((d1x, d1y)), np.hstack((-d1x, -d1y)))),
            np.hstack((np.zeros(n_points), np.ones(n_points))))
    return X, y.reshape(-1, 1)

n_points = 2500
X, y = generate_spiral_dataset(n_points)

# %%
plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0')
plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1')
plt.legend()
plt.show()

# %%
# Normalize data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='binary_crossentropy',
              metrics=['accuracy'])

n_epochs = 60
epoch_images = []

for epoch in range(n_epochs):
    model.fit(X_train, y_train, epochs=1, verbose=0)
    epoch_image = f'epoch_{epoch}.png'
    epoch_images.append(epoch_image)

    plot_save_decision_boundary(model, X_test, y_test, epoch, epoch_image)

# %%
from PIL import Image as Image_PIL

# Create the GIF
gif_filename = 'epoch_animation.gif'
images = [Image_PIL.open(epoch_image) for epoch_image in epoch_images]

duration = 0.15
images[0].save(gif_filename,
            format='GIF',
            append_images=images[1:],
            save_all=True,
            duration=duration*1000,
            loop=0)

# Delete the individual epoch images
for epoch_image in epoch_images:
    os.remove(epoch_image)

# %%
# Display the GIF
Image(filename=gif_filename)
